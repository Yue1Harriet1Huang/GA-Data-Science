# %% [markdown]
# ## Initial Project Dataset Submission

# %% [markdown]
# ### Shirin Hashim

# %% [markdown]
# ### September 24, 2014

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pylab
import matplotlib

# %matplotlib inline

# %% [markdown]
# #### Link to datasets:

# %% [markdown]
# All noise complaints in NYC from 9/21/2014 through 9/20/2014:

# %% [markdown]
# https://www.dropbox.com/s/ulvqmynzw9izxzu/311_Noise_Complaints_20140321_through_20140920.csv?dl=0

# %% [markdown]
# #### Brief Description:

# %% [markdown]
# This is a subset of NYC OpenData's 311 call data, limited to noise complaints between 3/21/2014 and 9/20/2014.

# %% [markdown]
# ##### Fields in the dataset that are relevant:

# %%
noise = pd.read_csv("C:/Users/shashim2/Dropbox/Columbia/Fall 2014/GA Data Science/311_Noise_Complaints_20140321_through_20140920.csv")
#noise = pd.read_csv("/Users/shirinhashim/Dropbox/Columbia/Fall 2014/GA Data Science/311_Noise_Complaints_20140321_through_20140920.csv")

noise.columns.values
# Out:
# array(['Unique Key', 'Created Date', 'Closed Date', 'Agency',
#        'Agency Name', 'Complaint Type', 'Descriptor', 'Location Type',
#        'Incident Zip', 'Incident Address', 'Street Name', 'Cross Street 1',
#        'Cross Street 2', 'Intersection Street 1', 'Intersection Street 2',
#        'Address Type', 'City', 'Landmark', 'Facility Type', 'Status',
#        'Due Date', 'Resolution Action Updated Date', 'Community Board',
#        'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Park Facility Name', 'Park Borough',
#        'School Name', 'School Number', 'School Region', 'School Code',
#        'School Phone Number', 'School Address', 'School City',
#        'School State', 'School Zip', 'School Not Found',
#        'School or Citywide Complaint', 'Vehicle Type',
#        'Taxi Company Borough', 'Taxi Pick Up Location',
#        'Bridge Highway Name', 'Bridge Highway Direction', 'Road Ramp',
# ...

# %% [markdown]
# I will most likely use the created date, address/zipcode/borough/city, type of complaint, description, location type, close date, and perhaps the specific locations.

# %% [markdown]
# ##### Describe function of the dataset:

# %%
noise.describe()
# Out:
#             Unique Key  Incident Zip  X Coordinate (State Plane)  \
# count     88520.000000  88424.000000                87854.000000
# mean   28336763.790307  10622.471919              1000331.227480
# std      346665.034315    632.743213                17379.066115
# min    27679565.000000     83.000000               914381.000000
# 25%    28059842.500000  10029.000000               989562.000000
# 50%    28323987.500000  10460.000000               998314.000000
# 75%    28645687.750000  11221.000000              1007557.000000
# max    28923037.000000  11697.000000              1067181.000000
#
#        Y Coordinate (State Plane)  School or Citywide Complaint  Vehicle Type  \
# count                87854.000000                             0             0
# mean                210562.097343                           NaN           NaN
# std                  27507.040030                           NaN           NaN
# ...
